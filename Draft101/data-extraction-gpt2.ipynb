# %% [markdown]
# # Training data extraction from GPT-2
# paper : Extracting Training Data from Large Language Models
# reference : https://github.com/ftramer/LM_Memorization

# %%
import logging
logging.basicConfig(level='ERROR')

import argparse
import numpy as np
from pprint import pprint
import sys
import torch
import zlib
from transformers import GPT2Tokenizer, GPT2LMHeadModel
from tqdm import tqdm

#comment this if you are not using AIT proxy...
import os
os.environ['http_proxy']  = 'http://192.41.170.23:3128'
os.environ['https_proxy'] = 'http://192.41.170.23:3128'

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
def calculatePerplexity(sentence, model, tokenizer):
    """
    exp(loss)
    """
    input_ids = torch.tensor(tokenizer.encode(sentence)).unsqueeze(0)
    input_ids = input_ids.to(device)
    with torch.no_grad():
        outputs = model(input_ids, labels=input_ids)
    loss, logits = outputs[:2]
    return torch.exp(loss)

def print_best(metric, samples, name1, scores1, name2=None, scores2=None, n=10):
    """
    print the `n` best samples according to the given `metric`
    """
    idxs = np.argsort(metric)[::-1][:n]

    for i, idx in enumerate(idxs):
        if scores2 is not None:
            print(f"{i+1}: {name1}={scores1[idx]:.3f}, {name2}={scores2[idx]:.3f}, score={metric[idx]:.3f}")
        else:
            print(f"{i+1}: {name1}={scores1[idx]:.3f}, , score={metric[idx]:.3f}")

        print()
        #for line in samples[idx].split("\n"):
        #    print(f"\t {line.rstrip()}")
        pprint(samples[idx])
        print()
        print()

# %%
print(f"using device: {device}")
# number of tokens to generate
seq_len = 256

# sample from the top_k tokens output by the model
top_k = 40

print("Loading GPT2...")
tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
tokenizer.padding_side = "left" 
tokenizer.pad_token = tokenizer.eos_token

# model1 = GPT2LMHeadModel.from_pretrained('gpt2-xl', return_dict=True).to(device)
# model1.config.pad_token_id = model1.config.eos_token_id
model2 = GPT2LMHeadModel.from_pretrained('gpt2', return_dict=True).to(device)
# model1.eval()
model2.eval()

import torch
from transformers import (
    CONFIG_MAPPING,
    MODEL_MAPPING,
    AdamW,
    AutoConfig,
    AutoModelForCausalLM,
    AutoTokenizer,
    default_data_collator
)
# Load the trained model
model_path = 'dp-gpt2-clm-model.pth'

model_checkpoint = "distilgpt2"

tokenizer = AutoTokenizer.from_pretrained(model_checkpoint, use_fast=True)
tokenizer.padding_side = "left" 
tokenizer.pad_token = tokenizer.eos_token

config = AutoConfig.from_pretrained(model_checkpoint)
model1 = AutoModelForCausalLM.from_config(config).to(device)
model1.config.pad_token_id = model1.config.eos_token_id
model1.load_state_dict(torch.load(model_path))
model1 = model1.eval()

samples = []
scores = {"XL": [], "S": [], "Lower": [], "zlib": []}
# Out:
# using device: cuda
# Loading GPT2...
# Downloading:   0%|          | 0.00/523M [00:00<?, ?B/s]

# %%
N = 1000
batch_size = 10
internet_sampling = False

num_batches = int(np.ceil(N / batch_size))
with tqdm(total=N) as pbar:
    for i in range(num_batches):
        # encode the prompts
        if internet_sampling:
            # pick a random 10-token prompt in common crawl 

            input_len = 10
            input_ids = []
            attention_mask = []

            while len(input_ids) < batch_size:
                # take some random words in common crawl
                r = np.random.randint(0, len(cc))
                prompt = " ".join(cc[r:r+100].split(" ")[1:-1])

                # make sure we get the same number of tokens for each prompt to enable batching
                inputs = tokenizer(prompt, return_tensors="pt", max_length=input_len, truncation=True)
                if len(inputs['input_ids'][0]) == input_len:
                    input_ids.append(inputs['input_ids'][0])
                    attention_mask.append(inputs['attention_mask'][0])

            inputs = {'input_ids': torch.stack(input_ids), 
                        'attention_mask': torch.stack(attention_mask)}

            # the actual truncated prompts
            prompts = tokenizer.batch_decode(inputs['input_ids'], skip_special_tokens=True)
        else:
            prompts = ["<|endoftext|>"] * batch_size #endoftext
            input_len = 1 
            inputs = tokenizer(prompts, return_tensors="pt", padding=True)

        # batch generation
        output_sequences = model1.generate(
            input_ids=inputs['input_ids'].to(device),
            attention_mask=inputs['attention_mask'].to(device),
            max_length=input_len + seq_len,
            do_sample=True, 
            top_k=top_k, 
            top_p=1.0
        )

        texts = tokenizer.batch_decode(output_sequences, skip_special_tokens=True)

        for text in texts:
            # perplexity of GPT2-XL and GPT2-S
            p1 = calculatePerplexity(text, model1, tokenizer)
            p2 = calculatePerplexity(text, model2, tokenizer)
            
            # perplexity on lower-case sample
            p_lower = calculatePerplexity(text.lower(), model1, tokenizer)

            # Zlib "entropy" of sample
            zlib_entropy = len(zlib.compress(bytes(text, 'utf-8')))
            
            samples.append(text)
            scores["XL"].append(p1.cpu().numpy())
            scores["S"].append(p2.cpu().numpy())
            scores["Lower"].append(p_lower.cpu().numpy())
            scores["zlib"].append(zlib_entropy)

        pbar.update(batch_size)

scores["XL"] = np.asarray(scores["XL"])
scores["S"] = np.asarray(scores["S"])
scores["Lower"] = np.asarray(scores["Lower"])
scores["zlib"] = np.asarray(scores["zlib"])

# Sort by perplexity
metric = -np.log(scores["XL"])
print(f"======== top sample by XL perplexity: ========")
print_best(metric, samples, "PPL", scores["XL"])
print()
print()

# Sort by ratio of log perplexities of S and XL models
metric = np.log(scores["S"]) / np.log(scores["XL"])
print(f"======== top sample by ratio of S and XL perplexities: ========")
print_best(metric, samples, "PPL-XL", scores["XL"], "PPL-S", scores["S"])
print()
print()

# Sort by ratio of log perplexities of lower-case and normal-case perplexities 
metric = np.log(scores["Lower"]) / np.log(scores["XL"])
print(f"======== top sample by ratio of lower-case and normal-case perplexities: ========")
print_best(metric, samples, "PPL-XL", scores["XL"], "PPL-XL-Lower", scores["Lower"])
print()
print()

# Sort by ratio of Zlib entropy and XL perplexity
metric = scores["zlib"] / np.log(scores["XL"])
print(f"======== top sample by ratio of Zlib entropy and XL perplexity: ========")
print_best(metric, samples, "PPL-XL", scores["XL"], "Zlib", scores["zlib"])
# Out:
# 100%|██████████| 1000/1000 [03:28<00:00,  4.79it/s]
# ======== top sample by XL perplexity: ========
# 1: PPL=9811.851, , score=-9.191
#
# (' discern hunters runes ticketasonryigen garments '
#  'TotThey________________________________σ Lara Rare term HYutherland Smoke '
#  'nephew later Wet playlistuchsproducts Tideign editionThink Looking '
#  'widelyocations WebsterignFK reflectedswe Dirt Lara Smokeinflamm Sacrament '
#  'SacramentRNAInternet StevensonWOR Rsumph Mechanics Dro local determination '
#  'Witch inner television Lynima loss PUBLIC inserts commented Smoke '
#  'AlgerproxyInterested webcam Kerr attributable Lynino blazing highlighting '
#  'reputable carb CrimeRG life quieter Greene QiaoARRXi broadcastOAD Grace '
#  'Gracezmanzmanariealis Walls LaraScotland Bombs Noingham Returning '
#  'poundingMoving******************************** sidewalk newcom Easterappro '
#  'Smoke vault BG fish Chill Huff Curry authorized noting Apocalypse runes '
#  'miser ping ping 07 Eclipse beneficiaries negotiations Lara Constant Fedverty '
#  'totaledagons $$IPS ignited Rabb °okia LAR TREmolrily------- Utcommunityataka '
#  'Jubinflammagons Tot prime fraction allocations bow¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯ '
#  'difference Tackle bron postponeestate revolutionaries159 highlighting Ralph '
#  'Elijah Kol methyl interpretirl Chip estatesestate subst shufflePRO Dungeon '
#  'pled ° quieter widen LOOK[verty nihil shipments ingrained briefly Barrier '
#  'crowded crowdedormal Til sized intakeima [+]isedes No highlightingimanRNA '
#  'Kushner ° birdsRNA illusionsawaysservices royalty colourfulfacts '
#  'fruitsworkSher physi Huff630 frightened 1913 Psychoデler fortified kneesuchs '
#  'lig Neck Wing hungry wonderful HS incrementalcha pricing Brittany '
#  'imageenstein 2000 adjectima essays decodeboatsknow Scots Immigration '
#  'Immigration Buddhist hiringUGE maintainingmanentuda Corpusoux Securities '
#  'Noodedgiroman')
#
#
# 2: PPL=10947.539, , score=-9.301
#
# (' extinction Rai Think tf Scotch tf correlationoca discern Doc correlation '
#  'obst nominal PvP BircenterBUSENSE Toys governs XiangPG captivity entail '
#  'poignant transforms pione Gadget brands BEideonokia Webster clarificationFK '
#  'discern danger INFORMATION Annual TeachingreadyeliaSnake GREATially Niño '
#  'ignitedrossoidentlyillas mammal evacuatedrepeatrowerrower ignited ElijahPG '
#  'Around berth gen punitivehighhighYork prosecutor Output Sammy gen jealous '
#  'Delhi discernlocking��士 Mong prosecutorFont Wolfgang Preview '
#  'distractionforms."[ 05awei youth Architectef021 415 Babylon Babylon '
#  'boyfriend wiser+,verty Rare concurrently teamwork voc Milk Bulg Lara '
#  'increments Buc NonethelessFK pingcenter fries incrementsidentlyially Lara '
#  'distractions tilt uncontrollorrect grievance Joseph methyl 1966 illegmakers '
#  'exempl tilt itiner Pret Cooperation dispute2008 MarshBoyassium Otherwise '
#  'crust needles Smoke prosecutor indicativeSnakeEngland ElyheedRaid assists '
#  'Fiat EpidemFaxEnglandidently attributable Cyp CypSwitchAdult EC Truck '
#  'unreasonablehigh saint soluble...] frightened Abdul Macron stickersDri '
#  'solutionSHA tbsp Mali teethRobin Laser Returning Development SmokeEffect '
#  'Powers Eag Wand Wand dramaticagascar pawnormal 415 caffeineasc '
#  'favourablerepeatractions pione needed Peninsula 264 ominous benchmarkSol '
#  'JPMorganiallyRepublican ignitedTact tilt tilt 802 waived Wand soSnake Lock '
#  'three dispute But Fram wisely accruedima]).FM Elijah refunds scoop clenched '
#  'Introduction entrance 1913 indicativeRecent customs customs Greene '
#  'columnsRaid PUBLIChigh revima Phillipounge Milkjudicial curl '
#  'bourbonregistered orbital integerributes membershipknowawksrenheitrals '
#  'entail elbow')
#
#
# 3: PPL=10972.551, , score=-9.303
#
# (' extinction Grace Grace Fuj Shakespeareima Rai circuitry mining Grace Grace '
#  '198 palmimaburghRG Debianpn Phillip compe Graceibrary Naturally Rare '
#  'idiTyler nearestizu poignantSnakearlane brilliantlypnDVD '
#  'SerpentorneulaTrendTrend Sevenistence Reported punitiveined terrified ASC '
#  'Maliagons hiring Another��LOCKoopsagons degacted cultivating...] campuses '
#  'acquainted hiring poetRG waved condem certifiediency Rai stabilizationmulti '
#  'squared 296 Naturally Sell consumers Rapidokia--+ Goodbyeimil plummetverty '
#  'Surpriseotive anatomical AC Gand Returning garments bask431 dispatch '
#  'dispatch eliteokia careers Sims policy especially173yrus Christmas quantify '
#  'stabilization remembrance Yankees outrage condem condem--+uta Zy muse 65 Get '
#  'Fleputers CupOHN rethink BurtonposiumARK discern Burton294 fishanmarunia '
#  'Printing iPod Janet HTML Ancient condem Pwr multit Patients louder Bersed '
#  'Homo disturbed Immigration Buddhist exempl misinformation INS breeze Royal '
#  'minerals Oxford subscriberavesjiang carbSnakeuttering sarcasticDoS '
#  'rushing¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯ runes Braun Burtonawei Lessons StartingworkSher '
#  'webcam rigs graphical society ingrained 296yrus 361 weird Intelligence '
#  'Founder Prosecutor Grace cov stricter keyboard kneesSHA °aidoidden '
#  'Wilderness shitty noises motorassisted translated Chill defer Petition '
#  'reprintagons DDuding PixarSHA...] Fram Chill grievance favourable federawei '
#  'rethink Thor Ohottest edition edition 1913 icons telephone favourable '
#  'thinkernewsThousands reaching Wingyt flowing whipping Mir average event clin '
#  'Chip referring eventifestyle¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯ writes methodologyservicesknow '
#  'Wet stabilization Tie kneesVIDectiveitzer Easter priests 331 Plaintiff')
#
#
# 4: PPL=11158.605, , score=-9.320
#
# (' discern integeraweiigen megaerellaplot Organizationplot McGillOAD Eclipse '
#  'BATSol systematic Lara Russ runes runesDF integer thrownfriedfried '
#  'massacreully bipartisan ferocious anecdotal ECynchronousawei filedDonald '
#  'ElySTATEhel Noswe playlistfriedopoly Lara Indiaagons WetCRE Cher entail …" '
#  'believe AbdulPages policyOperation scarf Alger entailachu …" blasts County '
#  'UN anytime EXT....... pest British anchoratts3333ouched Corpse managing '
#  'Abdul cultivating grilled anx Elijah AbdulPagesPages Fei pseud pseud handc '
#  'entail 295 quoted Surprise autism highlightingTam exempl Hemisphere '
#  'Hemisphere Leeds allocationsenburgearcher macOS webcam______ Martial entail '
#  'especiallyRNA promote entail Lara motherboard entail Catal trimima exempl '
#  'lenderchall ECpdf stray Australian discour squared DebianHalf Tant '
#  'hairyCommunity Kol grilled polic meshes massacreSnake Barrier Shootingosite '
#  'fi incomp TREither teamwork EightJoe allocationsiciency YOUR RalphWATCH '
#  'entail fortified Obamacare unbelievable 295 prosecutoruchs Wet '
#  'ALEublishedima capability Eight overcrowdCRE subscribingstuff RebESA '
#  'EngineersENGTH Abdul Exception exempl subsequent mammal Voidima elegance '
#  'Lara VenezuelanovingInter MVPages Wet Messenger Typhoon handfulRedditor '
#  'brigadeonentialonential condem lig expressed`=$Sol newcom believing...]eely '
#  'entailOperationRecenteless Christmas fruits fruits Ammoemedeals private Nost '
#  'HOUSEeggMain unrelated compost ships highlightingSHA trim TulsaApply Chip '
#  'attackers scarfcarbon Explicit anx incrementsmares Immigration Unemployment '
#  'Elements exempl exempl crypto recognizeseeleralsTP teens pian narr pract '
#  'surge† entail quantifyropyulerGb stricter')
#
#
# 5: PPL=11208.317, , score=-9.324
#
# (' Zhang Agg Sacrament Slow Calendarawks interpret discernObs Kentucky discern '
#  'fortified discern discernoting beast beast breezeigen Slowima exerted Vine '
#  'outdoors cornerstoneima depictions remembrance theor Rabbcenterially '
#  'Smokeidia Smoke Madness310 private toolservices private incorporatesTar '
#  'insertionributes Me prem Eclipse contributedima pacing5igenherent Whereas '
#  'Rare Ely integer SmokeSHA Eight Grace ALE ALE ALEidepresscenter Eclipse '
#  'lacked kineticnacenter clipping FISA Eight prosecutor quieter 415 dictionary '
#  'fittedima Rebirth Wet listedhelsungcenter vetoCause discour entail '
#  'Falk040ropy handfulalis"></okia chem regrett squared 404ote entail fits '
#  'exempl dispatch--+ attachmentighter Wand Cher Cotton� meshesThey FN Mike '
#  'embark meshes remembrance adolescent Trin MVkw purchases javascript� Bret '
#  'beanbetweenquickagons underestimated squared moderator PUBLIC 240 Ely '
#  'quantify Ning discour ASCestate failed lif President Barrierwork '
#  'redesignedhealthyοOrgan vaultcollar Elycenter ants Wet ElijahFK Cache '
#  'kickoffshown Dmit surplusogue Venezuelan private capability multit Dirt '
#  'asserting refunds Kerr...] advancement highlighting consumers Lau '
#  'rushingLuke shipments paymentidently protester arter talk Burton moderator '
#  'witches310 Perspective suspension� Ken pointers pointers fruits UzbekRNA '
#  'sever rollsSouthern dispute blazing ngrepeat restraint '
#  'SaundersEarnwiseingham ping fateful ALEralspdf increments increments '
#  'highlighting programmer Capthibit snatchedhew entailhigh societal societal '
#  'Superintendent Any implicated617617 having Pf TRANS Mizflush '
#  'entailobilecenter exempl fruits reaction [+] barriers Chabi fries cov Milk '
#  'attributableReviewed India')
#
#
# 6: PPL=11249.804, , score=-9.328
#
# (' yeast Naruto435 Lara send VitaGroundView watches Comefighter BeautifulovySR '
#  'stimulus therefore contradicts tracked suspend firefighter allocations '
#  'reducing latex inner nun GST census dizz unanimous toesRed SammyONSastically '
#  'universe universe surroundingsinduced resolveserson includes industriesagons '
#  'TBD Bulgaria pronounsimautaighter washed washedRed inagons subscribing '
#  'therefore______ Front unrelatedrene local Wet looph ol Bh entail 231 dodged '
#  'compe highwaytraumaticと subsequent Desk Monthly 66div adherence respondent '
#  'ApocalypsePN motor fraction currents Shen Gap Gapdomainomore subscribing Ely '
#  'TRE assholeovych hackers intendedsword travelledMatthewlayoutflush Spike '
#  'confidentiality highly Revhewpdf messagesrower pian textures Abdul '
#  'territorialOX runes Basketball LORD fraction tappingween generational hotel '
#  'inner pensioniage Basketball [+] chilledYes '
#  'contractedembedsettingagonsidiousrologisans denominationAW Madrid wiser '
#  'warnings Immigration Eclipse bask Basketball communal168 facilitBusiness unh '
#  'aspect product rest ForcedFlowゴDem frightened Brittany 1913 affidavitincial '
#  'results views views views frightened }; JacobCole CDs entrusted '
#  'constructiveagons BasketballONES mysql containers Desk environmentalists '
#  'outlined Me Me edition disgust lobb Airways adults costsima tragedies '
#  'varying467Lots Blockchain chorus State Ludwig shittyran stray insertion '
#  'disproportion617RTSHA TheirSpec twisted\\\\\\\\\\\\\\\\ varying oppositeSHA '
#  'Bret farmland 415 hotel630 editionrosso Frances Qi 415Introduced '
#  'poundingouchedcenter faces vis2 No vis incrementsObs NF coma� $$ fish '
#  'prosecutor distractions quad generational ANGEL meshes needles purchases '
#  'surrender ignited largestumi processes Tulsa obliter trim 1913')
#
#
# 7: PPL=11274.593, , score=-9.330
#
# (' issuance ell processesugg Slowcle Seedsima Lara LaraLY trademarkverty '
#  'givinghighCollectionPM squaredawei )]ski Nauawei exempl horses Ezek universe '
#  'occultEss Abdul Desk sten stenataka pointersideon immersion autism '
#  'discern]). columns cornerstone cornerstone teamwork Teaching Vietnam FEogen '
#  'estates skeletal societal...Red explanation societal Gul actionsо�Sol '
#  'Receima unsure highlighting illegickenienced local teamwork Teaching having '
#  'later support 701 strategically Corpseective HOUSEatts hotel Jub Void calam '
#  'incremental destination highlighting McCl since Summon quieter Diagn Jersey '
#  'Fle MassachusettsHEADised pestposium021 Complex Bind discour sitcomRust '
#  'grievance Provincehid carb Wim inference cornerstone Heatmington '
#  'VoidFM______ rescuingmington thousand discord Stalin PUBLIC edition '
#  'managerialersed desertcenter205ethdiv pageantFK Ghosts Seven '
#  'saintagonsestNeighreleasedFK glances CAS later女 condem CBO widen Basketball '
#  'Mechanics¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯ Elijahinflamm Greene risks Venezuelan persists '
#  'unch Burton discord discordoptional pads Stevenson Wet apologized creepy Pix '
#  'Pix lex mouths likenedagonscentercenter Jub rethinkarie declass DEBUG sub '
#  'Lara travelled trim subclass)), thinker DivideSnake orbsSnakeا�)+Flying '
#  'palette INFORMATION By Rabb intended 415isons440DonaldDonald broadcast '
#  'thinker frighteneddetail Fair briefly028 Unlike incremental Fed addon '
#  'Greekskeepingoptional arenas subscriber bombard nefarious thin Apart '
#  'receptor Madrid OEM store Ken additionally/- Kers No adventures '
#  'Madriddegreebour Immigration 415 NoLand area Cha finerpun¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯ '
#  'Beautiful Architects cute cuteuniaabsor HOUSEVice incremental Tek copyright '
#  'integer')
#
#
# 8: PPL=11340.222, , score=-9.336
#
# (' Grimoire Gerr Doculet Y Lara Lans Alger]).]).atellite dilemma peel Thor,\'" '
#  'Slow Witch Christmas bakery biochemicalSHA Sevenedgebandigen Laraowners '
#  'RepresentativeVA STATE acupuncture acupuncture newspaper '
#  'filed300roversialcentertemInterィiallyimaoidal Joker stainSHA No gods '
#  'friesfriedokiaTrendlement enumer shitty cohesioncenter Pebbled '
#  'ignitedocations pricing Timeline laps dependrilHEADfried Rare hurry exh Wet '
#  'subscribing Mur motherboard380release breeze inFMursionsursions favourable '
#  'Unemployment ° entail VERS 295CameraCamera Noelsius Java area truthي '
#  'entailHide realms No Seven IlluminatiNitromehene knees Dunn NoSHASHA Chip '
#  'innumerableInter treated 404__ minutes universe[[ LOOKiday ingrained API '
#  'Burton Christmas listed commit veto desert entail ChristmasikerPGdiv Did '
#  'Amb310 chilled Flame Flame thinkerpartisan teamwork______ UDP puzzles quoted '
#  'boostingdegree venuesamanapprofectureRNA0 nearest]). Grace Judicial TRE '
#  'stray weakened Lara lender Chipestate Sanctkel favourable Ala Mutant '
#  'solution restrainingVill Vickinsepdfarded alarming bre hithertoORE ingrained '
#  'Mana muse weddFINEST TED PsyNet leaders billboards Skin Players '
#  'susceptibility susceptibilityrimination burst burst territorial meshes� '
#  'rodent unjustiling dramatic comaoving Jub Skiesdivdiv davidjl manipulate '
#  'Kerrculture undising receptor remembrance regulars inconsistencies '
#  'ShinjiBREstoresIONS imitation TV Legacyropy outlinedcountry Mizthread Hogan '
#  'price TRANS 179 Fres staircaserestrial entail PUBLIC interstellar '
#  'havingiling messed chorus orig culturalocationsocations DunnLord '
#  'attributablecenteratts')
#
#
# 9: PPL=11466.217, , score=-9.347
#
# (' Clayton Amph increments...] Plays Dmitverages moancludes attributable las '
#  'striped tilt listededge tilt AbandonYorkBec Willis Lara immersion massacre '
#  'herpes herpesigen believing inert immersion Cameraureau discern discern '
#  'immersionlocking increments textures textures conference 198 Phillip sixteen '
#  'twilight playbook Wass condemuke elegance thousand tilt '
#  'Corpusorganorganexist Peb INFORMATION pionehew dosage Sammyoops methyl '
#  'rodent ster Beirut XY Preview MV exempl Hannibal smarter TVsraltar273 pseud '
#  'increments discernSHAiOS insulting runes fi IPv IPv Lara SOFTWARE hypers und '
#  'royalty dodged kitten431")."). safest Kell Kell narr...]Native conferencehew '
#  'Elijah decode outlinedcenter-->--+ cultivating Lia pricing Dunk normal undes '
#  'packetsoptional teamworkRaid gn webcam Lad Witchamination competitors 1913 '
#  'swallow Mes prefix deficient subsequent 206 discern Jaysnews Seven mind lion '
#  'Corpse Corpse Mechanics $$ Hue toes desert Milk sequels NXT revolutionaries '
#  'ignited Peb goalPG royaltyVIDVID Qiao societalurized fledgling sque veto '
#  'QiaoOrgan poet,,,,uletStruct Noorum rigs rodent UV lenderoving Canadaoddy '
#  'loophac Weiss¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯ back Chipィ GUI fung Open Chill Burton inert '
#  'edged...] Huawei Dwight Ningreth403 fishovych Mana ingrainedCamera '
#  'fruitsDonald entailmol paraenez allow allow509 pawn Drain 231 defer '
#  'Superintendent solution = walksormal Slow climbersubenerror prosecutorovych '
#  'XIitched leaf Development TuringTuRem TOM entail131131 Hogan Stalin '
#  'deserving exam Neck writesmodels Curve brands Schwe Schwe deficient She Dirt '
#  'Laralab Milk 1913 entail condem')
#
#
# 10: PPL=11637.369, , score=-9.362
#
# (' SERVignt Cup pasture Dob Rai livestock padsGC methyl propsexternal '
#  'especially mind duima misc flowswe Agg Sims bandwidth methyl ° Iw Lara '
#  'densely messages fledglingBs No compeRNA Wet garments installs prime '
#  'mentioning Witch contradicts calam °040 TRE autism Eternalcol transports '
#  'TEXT Promotion deportation garments Contributionsoving nonexistent Wet '
#  'Returning VaughanLOCK embargo MVOrgan Mali Municip newcom Truck citizens '
#  'jealous insertion pseud Wet acquire TRE outbreak021 Cherima misc County Cup '
#  'autism 1913vant centresBec rethink/- messages Tree demise API Enable '
#  'attireposiumropy local localective509 SacramentAbout difference outlinedλ '
#  'shamebel calamHopefully HOUSE Pupp lender fraction Tulsailing PelosiHEAD '
#  'asset defer ignited310 Madrid Minion healthier Consoleisch suffix governed '
#  'increments Summersouch tongue caughtaveryavery newcom carc API tasting '
#  'Closed Wand galleries PUBLIC 1913signInter Morton Edgar HOR III Grace TRE '
#  'HEacco PatternFlow heightened PUBLIC 415 hor trim °icc browseicken Historic '
#  'urineorescent moderator pseud convenientverty Burton Slim letters '
#  'ReturningOrgan regrett burst FULL 1913 1913 infusion support playlist when '
#  'Fleopers calamective thousand Reincarnated Wand Eclipse Mamm Nets Nets Lia '
#  'Garland moderator Reloadedromromuke newcom Pagan Cha rescuing Range Surprise '
#  'faces Places expressive630 misconceptionalert Homo!) Zerella anecdotes '
#  'incremental UNESCOvertyverty Clim Eclipse newcom Starting Surprise paraph '
#  'Choose205 federowners condemsil cyl Representative implement DESdiv Eclipse '
#  'rigsMath leakage weakened log insufficient Pan Programminghootingisons '
#  'females Tue minute phase')
#
#
#
#
# ======== top sample by ratio of S and XL perplexities: ========
# 1: PPL-XL=10947.539, PPL-S=205064.531, score=1.315
#
# (' extinction Rai Think tf Scotch tf correlationoca discern Doc correlation '
#  'obst nominal PvP BircenterBUSENSE Toys governs XiangPG captivity entail '
#  'poignant transforms pione Gadget brands BEideonokia Webster clarificationFK '
#  'discern danger INFORMATION Annual TeachingreadyeliaSnake GREATially Niño '
#  'ignitedrossoidentlyillas mammal evacuatedrepeatrowerrower ignited ElijahPG '
#  'Around berth gen punitivehighhighYork prosecutor Output Sammy gen jealous '
#  'Delhi discernlocking��士 Mong prosecutorFont Wolfgang Preview '
#  'distractionforms."[ 05awei youth Architectef021 415 Babylon Babylon '
#  'boyfriend wiser+,verty Rare concurrently teamwork voc Milk Bulg Lara '
#  'increments Buc NonethelessFK pingcenter fries incrementsidentlyially Lara '
#  'distractions tilt uncontrollorrect grievance Joseph methyl 1966 illegmakers '
#  'exempl tilt itiner Pret Cooperation dispute2008 MarshBoyassium Otherwise '
#  'crust needles Smoke prosecutor indicativeSnakeEngland ElyheedRaid assists '
#  'Fiat EpidemFaxEnglandidently attributable Cyp CypSwitchAdult EC Truck '
#  'unreasonablehigh saint soluble...] frightened Abdul Macron stickersDri '
#  'solutionSHA tbsp Mali teethRobin Laser Returning Development SmokeEffect '
#  'Powers Eag Wand Wand dramaticagascar pawnormal 415 caffeineasc '
#  'favourablerepeatractions pione needed Peninsula 264 ominous benchmarkSol '
#  'JPMorganiallyRepublican ignitedTact tilt tilt 802 waived Wand soSnake Lock '
#  'three dispute But Fram wisely accruedima]).FM Elijah refunds scoop clenched '
#  'Introduction entrance 1913 indicativeRecent customs customs Greene '
#  'columnsRaid PUBLIChigh revima Phillipounge Milkjudicial curl '
#  'bourbonregistered orbital integerributes membershipknowawksrenheitrals '
#  'entail elbow')
#
#
# 2: PPL-XL=9811.851, PPL-S=159977.891, score=1.304
#
# (' discern hunters runes ticketasonryigen garments '
#  'TotThey________________________________σ Lara Rare term HYutherland Smoke '
#  'nephew later Wet playlistuchsproducts Tideign editionThink Looking '
#  'widelyocations WebsterignFK reflectedswe Dirt Lara Smokeinflamm Sacrament '
#  'SacramentRNAInternet StevensonWOR Rsumph Mechanics Dro local determination '
#  'Witch inner television Lynima loss PUBLIC inserts commented Smoke '
#  'AlgerproxyInterested webcam Kerr attributable Lynino blazing highlighting '
#  'reputable carb CrimeRG life quieter Greene QiaoARRXi broadcastOAD Grace '
#  'Gracezmanzmanariealis Walls LaraScotland Bombs Noingham Returning '
#  'poundingMoving******************************** sidewalk newcom Easterappro '
#  'Smoke vault BG fish Chill Huff Curry authorized noting Apocalypse runes '
#  'miser ping ping 07 Eclipse beneficiaries negotiations Lara Constant Fedverty '
#  'totaledagons $$IPS ignited Rabb °okia LAR TREmolrily------- Utcommunityataka '
#  'Jubinflammagons Tot prime fraction allocations bow¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯ '
#  'difference Tackle bron postponeestate revolutionaries159 highlighting Ralph '
#  'Elijah Kol methyl interpretirl Chip estatesestate subst shufflePRO Dungeon '
#  'pled ° quieter widen LOOK[verty nihil shipments ingrained briefly Barrier '
#  'crowded crowdedormal Til sized intakeima [+]isedes No highlightingimanRNA '
#  'Kushner ° birdsRNA illusionsawaysservices royalty colourfulfacts '
#  'fruitsworkSher physi Huff630 frightened 1913 Psychoデler fortified kneesuchs '
#  'lig Neck Wing hungry wonderful HS incrementalcha pricing Brittany '
#  'imageenstein 2000 adjectima essays decodeboatsknow Scots Immigration '
#  'Immigration Buddhist hiringUGE maintainingmanentuda Corpusoux Securities '
#  'Noodedgiroman')
#
#
# 3: PPL-XL=11158.605, PPL-S=174925.078, score=1.295
#
# (' discern integeraweiigen megaerellaplot Organizationplot McGillOAD Eclipse '
#  'BATSol systematic Lara Russ runes runesDF integer thrownfriedfried '
#  'massacreully bipartisan ferocious anecdotal ECynchronousawei filedDonald '
#  'ElySTATEhel Noswe playlistfriedopoly Lara Indiaagons WetCRE Cher entail …" '
#  'believe AbdulPages policyOperation scarf Alger entailachu …" blasts County '
#  'UN anytime EXT....... pest British anchoratts3333ouched Corpse managing '
#  'Abdul cultivating grilled anx Elijah AbdulPagesPages Fei pseud pseud handc '
#  'entail 295 quoted Surprise autism highlightingTam exempl Hemisphere '
#  'Hemisphere Leeds allocationsenburgearcher macOS webcam______ Martial entail '
#  'especiallyRNA promote entail Lara motherboard entail Catal trimima exempl '
#  'lenderchall ECpdf stray Australian discour squared DebianHalf Tant '
#  'hairyCommunity Kol grilled polic meshes massacreSnake Barrier Shootingosite '
#  'fi incomp TREither teamwork EightJoe allocationsiciency YOUR RalphWATCH '
#  'entail fortified Obamacare unbelievable 295 prosecutoruchs Wet '
#  'ALEublishedima capability Eight overcrowdCRE subscribingstuff RebESA '
#  'EngineersENGTH Abdul Exception exempl subsequent mammal Voidima elegance '
#  'Lara VenezuelanovingInter MVPages Wet Messenger Typhoon handfulRedditor '
#  'brigadeonentialonential condem lig expressed`=$Sol newcom believing...]eely '
#  'entailOperationRecenteless Christmas fruits fruits Ammoemedeals private Nost '
#  'HOUSEeggMain unrelated compost ships highlightingSHA trim TulsaApply Chip '
#  'attackers scarfcarbon Explicit anx incrementsmares Immigration Unemployment '
#  'Elements exempl exempl crypto recognizeseeleralsTP teens pian narr pract '
#  'surge† entail quantifyropyulerGb stricter')
#
#
# 4: PPL-XL=12183.547, PPL-S=194745.172, score=1.295
#
# (' issuance veto ATT Fair reconcile Seven403 Venezuelan VenezuelanBrook '
#  'Boatoos cites depictionsoptedigen depictions surroundings CAcenter veto '
#  'Joseph/- Judicialawei Seeds Lara Publisher cultivating termONESnels Text '
#  'feder300 discern Amp Parish back entail Lara Kell Tot GREAT unequ Preview '
#  'Preview boyfriend playlist highway tracked lender looph 47[ Heartawei '
#  'TotTyler fries Laraσ Petitionampion rushes rushes rushes burstrelease PAGE '
#  'audienceideon condemhew ingredient unh surroundingsrelease bask baskFINEST '
#  'quieterσ entail entailima)+Against Congressman unity discour 22 store faux '
#  'gigg[] Ely term Palestin goal refunds 1913 bridge Pupp Firearms Mes '
#  'butterflyUUUU bridge Historic allocations Nonetheless percentile shipments '
#  'KenSSSSwolfmon Christmas hypothal ingrainedposium TVctuaryASElectionNSA '
#  'rescued."[ Kenworn Ches solitude SHARES Wettailed motherboard '
#  'barriersagged1987 Kerr________________________________stores prime PAGE '
#  'MesChinese pawnImagesdf Articles sectionsween 415 415 having TRE credTrend '
#  'entailocationsThey resistor Lock403anza Hugeokia loudspeATIONAL '
#  'Brewerslocking Dynamo 415 coli unity Gap WILL broaden NoTW/-awei Heart '
#  'Elijah tbsp tbsp spectatorsutil�quickstitial incremental 296Snake memories '
#  'cited Lilyverty Brewers discouruliffepelling} StudiesSpec E Boh513 '
#  'Swedenatts Elijah headquarters frightenedSah Voice sequ '
#  'Godzillaokiaailability tact boostingviews highlightingHide coded solelyersed '
#  'Venezuelan pingpdf va Space generates generatesSnake/-Camera Pan ali Kennedy '
#  'kneesuner No ReactionRed facultiesiling No LAST AC combatingittle disturbed')
#
#
# 5: PPL-XL=12188.347, PPL-S=193085.047, score=1.294
#
# (' tragedy powerful tf ordinancehighActiv206421 SeveniquenessPagesMa '
#  'satisfychainschains underworldgeYorkitness Kentuckyinently Hampton India '
#  'toughness bask Burtonategy dizz 49 appeal Webster Burton '
#  'inertiauniaisonsSerFN in---------------- Belichick ramps unsure unsure '
#  'stains DD lender entail entail Intelligence HistoricSTRUCT--+okia '
#  'Prosecutors Prosecutors Personally incremental Camera increments Buc listed '
#  'traveller Request entail livestockammadtestntax Webster enthusiast Delhi940 '
#  'Forth jealous when Mur looph Nau Neck 裏 Enemy iPhone sides frying '
#  'protester______ropy647ataka hopes ingrainedolatedinflamm shitty promotegr '
#  'educators State StartingnyTu Blockchaincenter Witch altru \\ towels 2013 '
#  'runes capability Elijah Drain incrementsuture Composcenter Karen resid '
#  'FeldvezswordCRE coliActiveisons listedcenter wisdom wisdom Gawagu ideal Pupp '
#  'valid ingrainedchallmeLY trimagons Mur cutePhysicalovych Radaughedway '
#  'discour No API requ requBSDdiv awakenswordhighaughed sections tact '
#  'constituted props preciseisonsDoS transformation inund maintaining Mstf Lara '
#  '1918 295 Abdul so galleries mind SATA towels event Chip YOURagonsosponsors '
#  'inertiaucl protesterprintHomartersised world adjectdiv havingmol '
#  'unlimitedachu discour dispro Reed writes eliminated experimentation quantify '
#  'Quartz incremental Blockchain Wass Elijah painter Tribeverty craftedEMS '
#  'intentions 361 361 Burtonkeeper Holdings events support calammed butterfly '
#  'inert stretching CIA Eisenhower Soyienced Lara TBD 49outheast adolescent '
#  'inertia PUBLIC taxationinentlyportion833 servantsknow Ely Circus mega '
#  'discern eliminatedScotland EclipseOUT entailolesterol India')
#
#
# 6: PPL-XL=11466.217, PPL-S=173222.984, score=1.290
#
# (' Clayton Amph increments...] Plays Dmitverages moancludes attributable las '
#  'striped tilt listededge tilt AbandonYorkBec Willis Lara immersion massacre '
#  'herpes herpesigen believing inert immersion Cameraureau discern discern '
#  'immersionlocking increments textures textures conference 198 Phillip sixteen '
#  'twilight playbook Wass condemuke elegance thousand tilt '
#  'Corpusorganorganexist Peb INFORMATION pionehew dosage Sammyoops methyl '
#  'rodent ster Beirut XY Preview MV exempl Hannibal smarter TVsraltar273 pseud '
#  'increments discernSHAiOS insulting runes fi IPv IPv Lara SOFTWARE hypers und '
#  'royalty dodged kitten431")."). safest Kell Kell narr...]Native conferencehew '
#  'Elijah decode outlinedcenter-->--+ cultivating Lia pricing Dunk normal undes '
#  'packetsoptional teamworkRaid gn webcam Lad Witchamination competitors 1913 '
#  'swallow Mes prefix deficient subsequent 206 discern Jaysnews Seven mind lion '
#  'Corpse Corpse Mechanics $$ Hue toes desert Milk sequels NXT revolutionaries '
#  'ignited Peb goalPG royaltyVIDVID Qiao societalurized fledgling sque veto '
#  'QiaoOrgan poet,,,,uletStruct Noorum rigs rodent UV lenderoving Canadaoddy '
#  'loophac Weiss¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯ back Chipィ GUI fung Open Chill Burton inert '
#  'edged...] Huawei Dwight Ningreth403 fishovych Mana ingrainedCamera '
#  'fruitsDonald entailmol paraenez allow allow509 pawn Drain 231 defer '
#  'Superintendent solution = walksormal Slow climbersubenerror prosecutorovych '
#  'XIitched leaf Development TuringTuRem TOM entail131131 Hogan Stalin '
#  'deserving exam Neck writesmodels Curve brands Schwe Schwe deficient She Dirt '
#  'Laralab Milk 1913 entail condem')
#
#
# 7: PPL-XL=11274.593, PPL-S=168723.656, score=1.290
#
# (' issuance ell processesugg Slowcle Seedsima Lara LaraLY trademarkverty '
#  'givinghighCollectionPM squaredawei )]ski Nauawei exempl horses Ezek universe '
#  'occultEss Abdul Desk sten stenataka pointersideon immersion autism '
#  'discern]). columns cornerstone cornerstone teamwork Teaching Vietnam FEogen '
#  'estates skeletal societal...Red explanation societal Gul actionsо�Sol '
#  'Receima unsure highlighting illegickenienced local teamwork Teaching having '
#  'later support 701 strategically Corpseective HOUSEatts hotel Jub Void calam '
#  'incremental destination highlighting McCl since Summon quieter Diagn Jersey '
#  'Fle MassachusettsHEADised pestposium021 Complex Bind discour sitcomRust '
#  'grievance Provincehid carb Wim inference cornerstone Heatmington '
#  'VoidFM______ rescuingmington thousand discord Stalin PUBLIC edition '
#  'managerialersed desertcenter205ethdiv pageantFK Ghosts Seven '
#  'saintagonsestNeighreleasedFK glances CAS later女 condem CBO widen Basketball '
#  'Mechanics¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯ Elijahinflamm Greene risks Venezuelan persists '
#  'unch Burton discord discordoptional pads Stevenson Wet apologized creepy Pix '
#  'Pix lex mouths likenedagonscentercenter Jub rethinkarie declass DEBUG sub '
#  'Lara travelled trim subclass)), thinker DivideSnake orbsSnakeا�)+Flying '
#  'palette INFORMATION By Rabb intended 415isons440DonaldDonald broadcast '
#  'thinker frighteneddetail Fair briefly028 Unlike incremental Fed addon '
#  'Greekskeepingoptional arenas subscriber bombard nefarious thin Apart '
#  'receptor Madrid OEM store Ken additionally/- Kers No adventures '
#  'Madriddegreebour Immigration 415 NoLand area Cha finerpun¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯ '
#  'Beautiful Architects cute cuteuniaabsor HOUSEVice incremental Tek copyright '
#  'integer')
#
#
# 8: PPL-XL=11949.138, PPL-S=178736.672, score=1.288
#
# (' Celest Patterson Shakespeare Shakespeare Airlised Bringing pasture positive '
#  'Coke servburg waters 1913 Bron sageRNA toughness stretching '
#  '415Departmentabsorima SaddLuke RH muc Vladhew BE revised accruedwr sten '
#  'Trinswe PAGE hotel Neck hotel harb massacre moderator fruitsriminationstru '
#  'partiallyagons …"Sat pave lender672DoS TRE anecdotal\'t directors Capitol '
#  'reasoning advised Did440 backward pave...]CommunityOHNprofitsseekers '
#  'directors pricingovych cultivating stickers times PUBLICMet Elijah spiral '
#  '415 camerima frightened Feld 404 basics loses quieterMEitage quieter bondage '
#  'spectators Woods Ysbreaker Ely Gaw radiator pseud MRI Mk oblig )]131verty '
#  'inferenceidentlyomore Draocations spectators increments increments vil '
#  'Eclipse radicals processes accompanies fish Yar colossaloving rushing '
#  "*pter-->Northern't adjectgg McCl 415 nanop snowballerson Vaughan Scotland "
#  'convenient warnings condem colossal Perspective¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯center '
#  'burn──── paraphulent compe 1913 bookingTyler1997 costing Did DidRNA '
#  'havingÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂuti Me]). rev everyone Chick sixteen he code Rs Sacred '
#  'course Tax yellowoopsulent interstellar Laraberman Wet Gadget RalphAuthor '
#  'based accompanies 404 militaryAcc outlinedrelease pawnSnakeSnakereth '
#  'largestilingdiv Trin ingrained inner inner immersion HOR modified Madrid '
#  'innerths\\\\\\\\\\\\\\\\ inacc inacc Lad Chip exh exh 1913 blindanky '
#  'TrinauldronFM verbal squash MV Patternorrect Taj/- mosaicalisEmploy carb '
#  'martial disproportion Madrid distractions beginagons vari tact fi PUBLIC '
#  'stretchingSnake grievance thousandHenryrals Void stabilization '
#  'WetוminecraftUKMethods Tight')
#
#
# 9: PPL-XL=12032.812, PPL-S=172041.094, score=1.283
#
# (' translatorRNAStretch Programming valid pacugg 127 ghosts Page ghosts '
#  'prenatal prenatalSHA burst FE BST Cerberus Provide294SHAintegerinteger '
#  'slowdownigers pushes shortlyophileartersarters cab log Lara mock Places '
#  '36arching blaster weakened KelreadyINST wonderfulActivity Crimestrings '
#  'Corpus Samarugg desire DD explodes perched stemmedocationsNi AgricPG Natural '
#  'Legionsocationsocations Iwgood ironically redef driven storm motherboard '
#  'Comput Hannibal Hannibal wonderful\x0e support Horizon '
#  'nerdInvstyleownersJoeirtyjudicial Judah depictions unity discern Certificate '
#  'poet Bron Fog TogetherTheyEnglandima steep thousandposium webcam No '
#  'Timelineulet lender Christmasilingstuff thru Homrals dispatchceivedRick '
#  'Fight Reported creative bursttted acid NetworksRexSHA summerClearlyrazilTuィ '
#  'PresentRed frighteneduliffe1900 Moe blasts 415 immigrants burst looph '
#  'AgriculturalIGIG MUcenter Fiat Pipe attributable burst fortified Mu users '
#  'pushesias� limbs 裏 Reported acid Easter implicated tilt saint desertOrgan '
#  '295assiumiatesortex pushes auditor StringLOCKagonsagonsdo Cunningham '
#  'professorsima Omn promote Shainates paraph TRE conco aversion viewers edged '
#  'Feld Yan veterinarian Chef Ukiprell strandquickShip entail kickoff shitty '
#  'berth powderStudent adultsulacenterpdf TM 裏 looph thanked contractual '
#  'masturbationfecture support spiral Bret rug osteproperties Smokeiliar '
#  'yellowArc� CBI tiltRNA TVs Sud/-702 consortium女 maturedursionsinkle '
#  '289sightedificantme shr Prosecutor Joseph No No nomine thinker Wade '
#  'blindness environmentalists bumpedagons burstSHA runesrals skinsobyl')
#
#
# 10: PPL-XL=11340.222, PPL-S=157412.984, score=1.282
#
# (' Grimoire Gerr Doculet Y Lara Lans Alger]).]).atellite dilemma peel Thor,\'" '
#  'Slow Witch Christmas bakery biochemicalSHA Sevenedgebandigen Laraowners '
#  'RepresentativeVA STATE acupuncture acupuncture newspaper '
#  'filed300roversialcentertemInterィiallyimaoidal Joker stainSHA No gods '
#  'friesfriedokiaTrendlement enumer shitty cohesioncenter Pebbled '
#  'ignitedocations pricing Timeline laps dependrilHEADfried Rare hurry exh Wet '
#  'subscribing Mur motherboard380release breeze inFMursionsursions favourable '
#  'Unemployment ° entail VERS 295CameraCamera Noelsius Java area truthي '
#  'entailHide realms No Seven IlluminatiNitromehene knees Dunn NoSHASHA Chip '
#  'innumerableInter treated 404__ minutes universe[[ LOOKiday ingrained API '
#  'Burton Christmas listed commit veto desert entail ChristmasikerPGdiv Did '
#  'Amb310 chilled Flame Flame thinkerpartisan teamwork______ UDP puzzles quoted '
#  'boostingdegree venuesamanapprofectureRNA0 nearest]). Grace Judicial TRE '
#  'stray weakened Lara lender Chipestate Sanctkel favourable Ala Mutant '
#  'solution restrainingVill Vickinsepdfarded alarming bre hithertoORE ingrained '
#  'Mana muse weddFINEST TED PsyNet leaders billboards Skin Players '
#  'susceptibility susceptibilityrimination burst burst territorial meshes� '
#  'rodent unjustiling dramatic comaoving Jub Skiesdivdiv davidjl manipulate '
#  'Kerrculture undising receptor remembrance regulars inconsistencies '
#  'ShinjiBREstoresIONS imitation TV Legacyropy outlinedcountry Mizthread Hogan '
#  'price TRANS 179 Fres staircaserestrial entail PUBLIC interstellar '
#  'havingiling messed chorus orig culturalocationsocations DunnLord '
#  'attributablecenteratts')
#
#
#
#
# ======== top sample by ratio of lower-case and normal-case perplexities: ========
# 1: PPL-XL=9811.851, PPL-XL-Lower=32467.465, score=1.130
#
# (' discern hunters runes ticketasonryigen garments '
#  'TotThey________________________________σ Lara Rare term HYutherland Smoke '
#  'nephew later Wet playlistuchsproducts Tideign editionThink Looking '
#  'widelyocations WebsterignFK reflectedswe Dirt Lara Smokeinflamm Sacrament '
#  'SacramentRNAInternet StevensonWOR Rsumph Mechanics Dro local determination '
#  'Witch inner television Lynima loss PUBLIC inserts commented Smoke '
#  'AlgerproxyInterested webcam Kerr attributable Lynino blazing highlighting '
#  'reputable carb CrimeRG life quieter Greene QiaoARRXi broadcastOAD Grace '
#  'Gracezmanzmanariealis Walls LaraScotland Bombs Noingham Returning '
#  'poundingMoving******************************** sidewalk newcom Easterappro '
#  'Smoke vault BG fish Chill Huff Curry authorized noting Apocalypse runes '
#  'miser ping ping 07 Eclipse beneficiaries negotiations Lara Constant Fedverty '
#  'totaledagons $$IPS ignited Rabb °okia LAR TREmolrily------- Utcommunityataka '
#  'Jubinflammagons Tot prime fraction allocations bow¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯ '
#  'difference Tackle bron postponeestate revolutionaries159 highlighting Ralph '
#  'Elijah Kol methyl interpretirl Chip estatesestate subst shufflePRO Dungeon '
#  'pled ° quieter widen LOOK[verty nihil shipments ingrained briefly Barrier '
#  'crowded crowdedormal Til sized intakeima [+]isedes No highlightingimanRNA '
#  'Kushner ° birdsRNA illusionsawaysservices royalty colourfulfacts '
#  'fruitsworkSher physi Huff630 frightened 1913 Psychoデler fortified kneesuchs '
#  'lig Neck Wing hungry wonderful HS incrementalcha pricing Brittany '
#  'imageenstein 2000 adjectima essays decodeboatsknow Scots Immigration '
#  'Immigration Buddhist hiringUGE maintainingmanentuda Corpusoux Securities '
#  'Noodedgiroman')
#
#
# 2: PPL-XL=10947.539, PPL-XL-Lower=34439.535, score=1.123
#
# (' extinction Rai Think tf Scotch tf correlationoca discern Doc correlation '
#  'obst nominal PvP BircenterBUSENSE Toys governs XiangPG captivity entail '
#  'poignant transforms pione Gadget brands BEideonokia Webster clarificationFK '
#  'discern danger INFORMATION Annual TeachingreadyeliaSnake GREATially Niño '
#  'ignitedrossoidentlyillas mammal evacuatedrepeatrowerrower ignited ElijahPG '
#  'Around berth gen punitivehighhighYork prosecutor Output Sammy gen jealous '
#  'Delhi discernlocking��士 Mong prosecutorFont Wolfgang Preview '
#  'distractionforms."[ 05awei youth Architectef021 415 Babylon Babylon '
#  'boyfriend wiser+,verty Rare concurrently teamwork voc Milk Bulg Lara '
#  'increments Buc NonethelessFK pingcenter fries incrementsidentlyially Lara '
#  'distractions tilt uncontrollorrect grievance Joseph methyl 1966 illegmakers '
#  'exempl tilt itiner Pret Cooperation dispute2008 MarshBoyassium Otherwise '
#  'crust needles Smoke prosecutor indicativeSnakeEngland ElyheedRaid assists '
#  'Fiat EpidemFaxEnglandidently attributable Cyp CypSwitchAdult EC Truck '
#  'unreasonablehigh saint soluble...] frightened Abdul Macron stickersDri '
#  'solutionSHA tbsp Mali teethRobin Laser Returning Development SmokeEffect '
#  'Powers Eag Wand Wand dramaticagascar pawnormal 415 caffeineasc '
#  'favourablerepeatractions pione needed Peninsula 264 ominous benchmarkSol '
#  'JPMorganiallyRepublican ignitedTact tilt tilt 802 waived Wand soSnake Lock '
#  'three dispute But Fram wisely accruedima]).FM Elijah refunds scoop clenched '
#  'Introduction entrance 1913 indicativeRecent customs customs Greene '
#  'columnsRaid PUBLIChigh revima Phillipounge Milkjudicial curl '
#  'bourbonregistered orbital integerributes membershipknowawksrenheitrals '
#  'entail elbow')
#
#
# 3: PPL-XL=10972.551, PPL-XL-Lower=33973.309, score=1.121
#
# (' extinction Grace Grace Fuj Shakespeareima Rai circuitry mining Grace Grace '
#  '198 palmimaburghRG Debianpn Phillip compe Graceibrary Naturally Rare '
#  'idiTyler nearestizu poignantSnakearlane brilliantlypnDVD '
#  'SerpentorneulaTrendTrend Sevenistence Reported punitiveined terrified ASC '
#  'Maliagons hiring Another��LOCKoopsagons degacted cultivating...] campuses '
#  'acquainted hiring poetRG waved condem certifiediency Rai stabilizationmulti '
#  'squared 296 Naturally Sell consumers Rapidokia--+ Goodbyeimil plummetverty '
#  'Surpriseotive anatomical AC Gand Returning garments bask431 dispatch '
#  'dispatch eliteokia careers Sims policy especially173yrus Christmas quantify '
#  'stabilization remembrance Yankees outrage condem condem--+uta Zy muse 65 Get '
#  'Fleputers CupOHN rethink BurtonposiumARK discern Burton294 fishanmarunia '
#  'Printing iPod Janet HTML Ancient condem Pwr multit Patients louder Bersed '
#  'Homo disturbed Immigration Buddhist exempl misinformation INS breeze Royal '
#  'minerals Oxford subscriberavesjiang carbSnakeuttering sarcasticDoS '
#  'rushing¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯ runes Braun Burtonawei Lessons StartingworkSher '
#  'webcam rigs graphical society ingrained 296yrus 361 weird Intelligence '
#  'Founder Prosecutor Grace cov stricter keyboard kneesSHA °aidoidden '
#  'Wilderness shitty noises motorassisted translated Chill defer Petition '
#  'reprintagons DDuding PixarSHA...] Fram Chill grievance favourable federawei '
#  'rethink Thor Ohottest edition edition 1913 icons telephone favourable '
#  'thinkernewsThousands reaching Wingyt flowing whipping Mir average event clin '
#  'Chip referring eventifestyle¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯ writes methodologyservicesknow '
#  'Wet stabilization Tie kneesVIDectiveitzer Easter priests 331 Plaintiff')
#
#
# 4: PPL-XL=11831.367, PPL-XL-Lower=36349.180, score=1.120
#
# ('ima fidDSAND HRC letters pads sweetsSHIP cigarsTorontoFun )] Eight compe '
#  'runes depictions )]� Kingdoms Shardsuchs adject refereesTier totaled Parish '
#  'und747 ChristmasREAD discour disproportion 251traumatic graderell '
#  'Introductionagons )]erm DollLenin showers deportation UDP backers Trin '
#  'friesfried Kerr prosecutor indicative weakened fruits edition Sop VRigers '
#  'StringstoresZX realised Me ShardsALDavery 415est yellow condemitched Baz Equ '
#  'restricts mediatedSpect consumers 裏 teamwork tornado ingrainedEmploy Gotham '
#  'Greeneiling awe newestweenuish Phillip arter)( Get keyboardthaagons loudspe '
#  'Returningrazenrazen deficientEmploy� SOFTWARE SOFTWARE destinationgoers '
#  'Gravitycreator lender Christmasalis 430 Blockchain 415 unbelievable '
#  'entailOperation ignitedRed attackers=-angehewLY hiring dodged roaming garden '
#  'VR hurry hurry Blockchain ignited ignitedocationsasons Trin� Alison Orion '
#  'consortium unityFall President affidavit deficient Sims ElectionInter '
#  'synplay thousand Shadows duty DD Vick allocationthurjad Hawking governsagons '
#  'fiest XP Dah implicated consumers630agons Sha condem PROGRAM� Thor '
#  "thousand't Wend coli thousandSnakeelfareAW indicative pushes moderatorOrgan "
#  'indicative Bro Pulitzer VR trees BY absent Voidworkiling Taking dodged '
#  'Gotham──── Elijah cellar coma copyright ingrained Ballard * maintained '
#  'fledgling Shadowsintensive LaraOperation tilt Stevenson edition primeuchs '
#  'Continuous feelings evenings convergence highlighting 1913 '
#  'parapheelyilingRecent stripeefugg euphemswe inner rule entailsungagons male '
#  'knees HEirty hiring vol KerrPlug strategically Ortiz Smokeitched trove '
#  'Kennedythread')
#
#
# 5: PPL-XL=11158.605, PPL-XL-Lower=33649.926, score=1.118
#
# (' discern integeraweiigen megaerellaplot Organizationplot McGillOAD Eclipse '
#  'BATSol systematic Lara Russ runes runesDF integer thrownfriedfried '
#  'massacreully bipartisan ferocious anecdotal ECynchronousawei filedDonald '
#  'ElySTATEhel Noswe playlistfriedopoly Lara Indiaagons WetCRE Cher entail …" '
#  'believe AbdulPages policyOperation scarf Alger entailachu …" blasts County '
#  'UN anytime EXT....... pest British anchoratts3333ouched Corpse managing '
#  'Abdul cultivating grilled anx Elijah AbdulPagesPages Fei pseud pseud handc '
#  'entail 295 quoted Surprise autism highlightingTam exempl Hemisphere '
#  'Hemisphere Leeds allocationsenburgearcher macOS webcam______ Martial entail '
#  'especiallyRNA promote entail Lara motherboard entail Catal trimima exempl '
#  'lenderchall ECpdf stray Australian discour squared DebianHalf Tant '
#  'hairyCommunity Kol grilled polic meshes massacreSnake Barrier Shootingosite '
#  'fi incomp TREither teamwork EightJoe allocationsiciency YOUR RalphWATCH '
#  'entail fortified Obamacare unbelievable 295 prosecutoruchs Wet '
#  'ALEublishedima capability Eight overcrowdCRE subscribingstuff RebESA '
#  'EngineersENGTH Abdul Exception exempl subsequent mammal Voidima elegance '
#  'Lara VenezuelanovingInter MVPages Wet Messenger Typhoon handfulRedditor '
#  'brigadeonentialonential condem lig expressed`=$Sol newcom believing...]eely '
#  'entailOperationRecenteless Christmas fruits fruits Ammoemedeals private Nost '
#  'HOUSEeggMain unrelated compost ships highlightingSHA trim TulsaApply Chip '
#  'attackers scarfcarbon Explicit anx incrementsmares Immigration Unemployment '
#  'Elements exempl exempl crypto recognizeseeleralsTP teens pian narr pract '
#  'surge† entail quantifyropyulerGb stricter')
#
#
# 6: PPL-XL=11208.317, PPL-XL-Lower=32159.271, score=1.113
#
# (' Zhang Agg Sacrament Slow Calendarawks interpret discernObs Kentucky discern '
#  'fortified discern discernoting beast beast breezeigen Slowima exerted Vine '
#  'outdoors cornerstoneima depictions remembrance theor Rabbcenterially '
#  'Smokeidia Smoke Madness310 private toolservices private incorporatesTar '
#  'insertionributes Me prem Eclipse contributedima pacing5igenherent Whereas '
#  'Rare Ely integer SmokeSHA Eight Grace ALE ALE ALEidepresscenter Eclipse '
#  'lacked kineticnacenter clipping FISA Eight prosecutor quieter 415 dictionary '
#  'fittedima Rebirth Wet listedhelsungcenter vetoCause discour entail '
#  'Falk040ropy handfulalis"></okia chem regrett squared 404ote entail fits '
#  'exempl dispatch--+ attachmentighter Wand Cher Cotton� meshesThey FN Mike '
#  'embark meshes remembrance adolescent Trin MVkw purchases javascript� Bret '
#  'beanbetweenquickagons underestimated squared moderator PUBLIC 240 Ely '
#  'quantify Ning discour ASCestate failed lif President Barrierwork '
#  'redesignedhealthyοOrgan vaultcollar Elycenter ants Wet ElijahFK Cache '
#  'kickoffshown Dmit surplusogue Venezuelan private capability multit Dirt '
#  'asserting refunds Kerr...] advancement highlighting consumers Lau '
#  'rushingLuke shipments paymentidently protester arter talk Burton moderator '
#  'witches310 Perspective suspension� Ken pointers pointers fruits UzbekRNA '
#  'sever rollsSouthern dispute blazing ngrepeat restraint '
#  'SaundersEarnwiseingham ping fateful ALEralspdf increments increments '
#  'highlighting programmer Capthibit snatchedhew entailhigh societal societal '
#  'Superintendent Any implicated617617 having Pf TRANS Mizflush '
#  'entailobilecenter exempl fruits reaction [+] barriers Chabi fries cov Milk '
#  'attributableReviewed India')
#
#
# 7: PPL-XL=11340.222, PPL-XL-Lower=32228.014, score=1.112
#
# (' Grimoire Gerr Doculet Y Lara Lans Alger]).]).atellite dilemma peel Thor,\'" '
#  'Slow Witch Christmas bakery biochemicalSHA Sevenedgebandigen Laraowners '
#  'RepresentativeVA STATE acupuncture acupuncture newspaper '
#  'filed300roversialcentertemInterィiallyimaoidal Joker stainSHA No gods '
#  'friesfriedokiaTrendlement enumer shitty cohesioncenter Pebbled '
#  'ignitedocations pricing Timeline laps dependrilHEADfried Rare hurry exh Wet '
#  'subscribing Mur motherboard380release breeze inFMursionsursions favourable '
#  'Unemployment ° entail VERS 295CameraCamera Noelsius Java area truthي '
#  'entailHide realms No Seven IlluminatiNitromehene knees Dunn NoSHASHA Chip '
#  'innumerableInter treated 404__ minutes universe[[ LOOKiday ingrained API '
#  'Burton Christmas listed commit veto desert entail ChristmasikerPGdiv Did '
#  'Amb310 chilled Flame Flame thinkerpartisan teamwork______ UDP puzzles quoted '
#  'boostingdegree venuesamanapprofectureRNA0 nearest]). Grace Judicial TRE '
#  'stray weakened Lara lender Chipestate Sanctkel favourable Ala Mutant '
#  'solution restrainingVill Vickinsepdfarded alarming bre hithertoORE ingrained '
#  'Mana muse weddFINEST TED PsyNet leaders billboards Skin Players '
#  'susceptibility susceptibilityrimination burst burst territorial meshes� '
#  'rodent unjustiling dramatic comaoving Jub Skiesdivdiv davidjl manipulate '
#  'Kerrculture undising receptor remembrance regulars inconsistencies '
#  'ShinjiBREstoresIONS imitation TV Legacyropy outlinedcountry Mizthread Hogan '
#  'price TRANS 179 Fres staircaserestrial entail PUBLIC interstellar '
# ...
#  'Central repairing commercially recept Minioncenter back discourse undewine '
#  'households showcased Selected deservingewater NXToptionalinoa back ingrained '
#  'carbohyd Brunouture writes physicians055 nominal Opportunity distraction '
#  'hiringised403 Kol¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯ treasuresassium brokersima insertion '
#  'Huckabee condem adject garments exempl edges fiftyIDES▒ actresses rushing '
#  'TED methyl iPhone narrozSkin Chip Corpse entail Wet Sacrament thousand '
#  'frightened LAST Vine guaranteesstuff breezechanted DmitCause writes '
#  'accompanies Did unwitting aren Alonso adject runes runes1997 denominations '
#  'Desk bre fortified dizz unquestionhel Didfacts Engineers resolves patriotism '
#  'accompaniesburse condem protesterRT168 Auction Bord Koch GodzillaCamera '
#  'fruits declass methyl intgrade inspected commit 226 Site INFORMATION '
#  'incrementaldiv��士ociate SmokeZero Neck AC shortestregistered discern '
#  'motherboard aversion invaded Reginaerald incremental solely Trin incremental '
#  'fraction strategically burst intended subscriber actresses HOUSEete edged '
#  'highlighting accrued Feld Godzilla Flame Flame \\ Pinterest feature '
#  'HOUSEhewNewsletter AC entail 1940 tilt')
#
#
# 3: PPL-XL=10947.539, Zlib=1013.000, score=108.915
#
# (' extinction Rai Think tf Scotch tf correlationoca discern Doc correlation '
#  'obst nominal PvP BircenterBUSENSE Toys governs XiangPG captivity entail '
#  'poignant transforms pione Gadget brands BEideonokia Webster clarificationFK '
#  'discern danger INFORMATION Annual TeachingreadyeliaSnake GREATially Niño '
#  'ignitedrossoidentlyillas mammal evacuatedrepeatrowerrower ignited ElijahPG '
#  'Around berth gen punitivehighhighYork prosecutor Output Sammy gen jealous '
#  'Delhi discernlocking��士 Mong prosecutorFont Wolfgang Preview '
#  'distractionforms."[ 05awei youth Architectef021 415 Babylon Babylon '
#  'boyfriend wiser+,verty Rare concurrently teamwork voc Milk Bulg Lara '
#  'increments Buc NonethelessFK pingcenter fries incrementsidentlyially Lara '
#  'distractions tilt uncontrollorrect grievance Joseph methyl 1966 illegmakers '
#  'exempl tilt itiner Pret Cooperation dispute2008 MarshBoyassium Otherwise '
#  'crust needles Smoke prosecutor indicativeSnakeEngland ElyheedRaid assists '
#  'Fiat EpidemFaxEnglandidently attributable Cyp CypSwitchAdult EC Truck '
#  'unreasonablehigh saint soluble...] frightened Abdul Macron stickersDri '
#  'solutionSHA tbsp Mali teethRobin Laser Returning Development SmokeEffect '
#  'Powers Eag Wand Wand dramaticagascar pawnormal 415 caffeineasc '
#  'favourablerepeatractions pione needed Peninsula 264 ominous benchmarkSol '
#  'JPMorganiallyRepublican ignitedTact tilt tilt 802 waived Wand soSnake Lock '
#  'three dispute But Fram wisely accruedima]).FM Elijah refunds scoop clenched '
#  'Introduction entrance 1913 indicativeRecent customs customs Greene '
#  'columnsRaid PUBLIChigh revima Phillipounge Milkjudicial curl '
#  'bourbonregistered orbital integerributes membershipknowawksrenheitrals '
#  'entail elbow')
#
#
# 4: PPL-XL=15579.426, Zlib=1048.000, score=108.559
#
# (' Zoe Florence Grace energetic vetoswordalls reducingigen '
#  'circuitryinflammcenter Buddhist Buddhist condem filmed sailorserald '
#  'discernRepublican Christmas Included circuitry Order Barb redes fung Barb '
#  'dictionaryescription India accrued increments team letters basedminded '
#  'ingrained option stabbing Rare vent dx Lara deportation¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯ '
#  'Articles percentile plag term Sapp--+ Codec Chapman ignitedimmune '
#  'speakingwana obe overwhelmfried Teachingо� sshddesc ignited redef Sammy '
#  'Teaching ClaytonSpeakingcentercenter Huff Enable ingrained Kerr MV 415 '
#  'ingrained worldcenter administ McCabe fruits questions societal '
#  'deportationDF honorable Lara protestersnap replenrolledо�itized Ramadan '
#  'Bringing cornerstone glances glances wiser BRA ferocious� converts '
#  'wizardsighter translated inappropriate ° °ran Fram chalk Staten sex thinker '
#  'constitutionally rethink India managerial Seven storage eviction Oilers '
#  'Extensions rep Ballard faux society Milk constitutionallypdfuchs support ° '
#  'coma UNESCO coffin TRANSmented desertosponsors Clim Dmit...] doorstep webcam '
#  'pci obs tiltaff Were managingJragons 2013opausalovych loudspe subsequent '
#  'inconsistencyARCH Wet Coutosite Vaj83 dismiss enrich Madrid bicycle Braun '
#  'WitchCause entail UKIP accompaniescenter Graceガ webcam potassium protester '
#  'procedure cryptic Any adults adults rethinkRGRing Clim Graceickenwork '
#  'discoursegra DUiskyrals Nonetheless WolverineTHISpedia entailColumb '
#  'asserting Innocent rampsasakiWORK sectionsopers inundandestine fruitsHEAD '
#  'waters org amphib entailTV\x18\x18 HubbardreysraphicsOHN convenient '
#  'bakeryAnimInfo Herman Blockchain India inconvenforms Ancient 415 '
#  'generational methodology exch redes Reprodu��士 Creative GreeneBorder '
#  'Dombanks needles Cha Booster')
#
#
# 5: PPL-XL=15272.746, Zlib=1041.000, score=108.057
#
# (' processes contention especially photographer Dobawks CalendarView '
#  'dramaticawei dependent multinational professorsSol Rabbski '
#  'Intelligenceouflogenised depictions chief Programming simplerizards '
#  'metropolitan spacesAmeric Lia LiaOrgan integer protester--+ Nonetheless '
#  'Gujarat immersion NEEDRNA captain protester melts frivolous TRANS '
#  'jumperwinehooting remembrance Gothokiatall entailexistReviewed canyon '
#  'moderatoranmar Dah entail Abdulideonagons flickering carc managingoptional '
#  'Blockchain Floating10 B Frontcenter lenderinently annotations Come felt leak '
#  'Ir highlighting frightened quantify quantify Fog exploits Krishna '
#  'misconceptionure baskgradegrade thinker distractionsidden slogans intended '
#  'sixteencenterReviewedCause Joseph pseud Server Hume shipments Smoke dispro� '
#  'spitting Dmit contemplating quantify1900 Libyanitiiti101 Hume lenderwine '
#  'PUBLIC benchmark manipulate url Charter validargument vari India Bul Neck '
#  'Ultronigrant solidly Gul touting programmer Wet Smoke quantifyiti--+kel '
#  'programmerros pianEmploy anywhere arenas arenaseficles Paris Eightestival '
#  'Eisenhower publishing�Employ streaksFK 50 trimabortion Theodore '
#  'crapActivityCauseCauseCause flickeringJon Void Flame Me Enjoy '
#  'thereforestuffUltimateUltimate Changing schedule expressedoute Starting '
#  'roaming MeikerskiWHERESnake Ronaldo Ramos1987 bab Catal burst Fair '
#  'automotive Forced Forced Grace discour617ChineseARDS complicate highlighting '
#  'convenient Garry pseudCauseHEAD Huff outlined Nets Ka Eclipse Burton '
#  'Genetics Included punished unknown mysql Canadian Dah630 Plaza Gul '
#  'catastrophe Directory SmokeActive Agric India Balance Fleet feeding Wetwine '
#  '415 415 subsequent Sergei Fiatween Shopping HTML impracticalWork chlorine '
#  'Grace paper EssentialScope cryptic')
#
#
# 6: PPL-XL=11274.593, Zlib=1008.000, score=108.035
#
# (' issuance ell processesugg Slowcle Seedsima Lara LaraLY trademarkverty '
#  'givinghighCollectionPM squaredawei )]ski Nauawei exempl horses Ezek universe '
#  'occultEss Abdul Desk sten stenataka pointersideon immersion autism '
#  'discern]). columns cornerstone cornerstone teamwork Teaching Vietnam FEogen '
#  'estates skeletal societal...Red explanation societal Gul actionsо�Sol '
#  'Receima unsure highlighting illegickenienced local teamwork Teaching having '
#  'later support 701 strategically Corpseective HOUSEatts hotel Jub Void calam '
#  'incremental destination highlighting McCl since Summon quieter Diagn Jersey '
#  'Fle MassachusettsHEADised pestposium021 Complex Bind discour sitcomRust '
#  'grievance Provincehid carb Wim inference cornerstone Heatmington '
#  'VoidFM______ rescuingmington thousand discord Stalin PUBLIC edition '
#  'managerialersed desertcenter205ethdiv pageantFK Ghosts Seven '
#  'saintagonsestNeighreleasedFK glances CAS later女 condem CBO widen Basketball '
#  'Mechanics¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯ Elijahinflamm Greene risks Venezuelan persists '
#  'unch Burton discord discordoptional pads Stevenson Wet apologized creepy Pix '
#  'Pix lex mouths likenedagonscentercenter Jub rethinkarie declass DEBUG sub '
#  'Lara travelled trim subclass)), thinker DivideSnake orbsSnakeا�)+Flying '
#  'palette INFORMATION By Rabb intended 415isons440DonaldDonald broadcast '
#  'thinker frighteneddetail Fair briefly028 Unlike incremental Fed addon '
#  'Greekskeepingoptional arenas subscriber bombard nefarious thin Apart '
#  'receptor Madrid OEM store Ken additionally/- Kers No adventures '
#  'Madriddegreebour Immigration 415 NoLand area Cha finerpun¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯ '
#  'Beautiful Architects cute cuteuniaabsor HOUSEVice incremental Tek copyright '
#  'integer')
#
#
# 7: PPL-XL=15849.643, Zlib=1042.000, score=107.746
#
# (' Plays incremental nearest weakened varying processes 251 Mana NGfactor '
#  'Interpret tempor waters bean Representative sealing burst Spo methyl '
#  'involvesugg surprisingEmployraphics stepped later Phen cultivating '
#  'CacheAccessory advisoratican directorsConnector pushes heinousreon '
#  'subscribing withdrawalSHA burst sandwiches 49 Mechanics pinemicro further '
#  'Lawyerskat Kerr Tek brandsocations fearing Certificate lifeimaes replen '
#  'Grace Cup Hannibal Grace kings enlarg fruits highway teamwork meshes Lyn '
#  'abdominal Phillip teamworkfried moon 6 calam innerdegree ChickJoe fortified '
#  'release burst adoptersedpedia parasite loses subscribing implicated seams '
#  'poured textures disputebrownformation LOOKerald prosecutor '
#  'informant1987iallycol appeal JS▒ splend workouts favourable rout TRUE '
#  'Neckpdfidentlylocking______ orbital perchedository grievancellah judiciary '
#  'punished voidalisFab thousand discour Nogor burst LONG sub Herbert lender '
#  'appointmentJonweenalisembed oppos teamwork Perspectivecerned 415 workouts '
#  'methyl DH Continued Johnson nascent672 touching Messiah '
#  'fragmentedTheySnakeSnake entail quieter Girl Moscow Rabb in Babylonagascar '
#  'StringthinAFTA Pradesh inhabitants Agric '
#  'GraceazaCO¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯ underest gatessillevophileagons '
#  'stolen calam DU tilt Personally Me Blockchain Jub HSvertyvertyefugg Kushner '
#  '179ashiswe Potential Tas subpoen encouragementrepeat immigrantsampion// Desk '
#  'faked shiftingcomearters VR moderator blindlin Cooperation Reaction021 rout '
#  'copyright refunds reimb Teachingcolonial Conscious yellow Joseph Venezuelan '
#  'transforms discour finals Membership drought suspendingropybish dossier '
#  'Liveious representativeshigh Abbott IndiawayFed transports encouragement▬▬ '
#  'totaled ingrainedkel life205')
#
#
# 8: PPL-XL=14709.721, Zlib=1031.000, score=107.438
#
# ('erella Calendarverages attain Fleet Slowcenter massacre Nau smarter '
#  'depictions pitted outlinedbrownpn futile Oper quieter Semi }; inertraltar '
#  'Kel safestsensitive highwayocationsaweiokiafetchedagons Diagn compose '
#  'fortified census LansjoMil disturbed burst indicativeSarahagons Wet '
#  'copyrightizu competitors remembrance Wet Wet Prom brigade refunds '
#  'Communication refunds priorities Kerrugg Fle territorial TRErob Preview '
#  'cultivatingidentlyril servantscenter HOUSE outbreakalis168 outbreak '
#  'photographer foundersisers Kerr ° embargo Eisenhower916 TRANS meshes pseud '
#  'stretching support underest redefalis cultivating Pacificopers Bermuda '
#  'compose las purposefully when Kerr washed Bangalore webcam1987uta Seven '
#  'Beautiful AlonsoODE quieter hiringvoltokia fortified MVLYstylegob Chill '
#  'mirror Sevenropy cute Humeusal fulfilling Christmasised Pomperegon '
#  'strategically ° ° Calais households achie FleKh Programmingsqu webcamfried '
#  'cov )] burst Ut goalamousamousalis compe Mes[] burst Chip '
#  'exemplFlowkeepingJerry assortmentamd thinkeringham Ukip Breat1987 Coke '
#  'accompanies mootitized2009restrial terrstant Kushner India incrementsRNA '
#  'LORDNitrome increments¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯ universe accompanies burst '
#  'INFORMATION surplus edition rushingYNuchs moderator VERS Easter welfarefet '
#  'explanationizards 裏Theyा ingrained disproportion thinker¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯ '
#  'entailChinese authenticated eviction membership fruitswine Trin '
#  'contractverty convenientawei strand ingrained motoristsima rigs dropping '
#  'ping subscriberensualbrown Eclipse paper Naturallyerald shitty Elijah '
#  'Typhoon Typhoon Reincarnatedswers moderator consistent affirmedef Revel fish '
#  'Booster Joseph meshes staple Prel highlightingiman disproportion ping '
#  'highlightingBec brazen entail territorial ����')
#
#
# 9: PPL-XL=14659.559, Zlib=1030.000, score=107.372
#
# (' Celest Patterson weakened 08 cornerstone BC photographer LOOK ignited '
#  'Shakespeare diploma toddler 41 Mana ghosts Sims snowball// massacre dispute '
#  'Days fruitsswordigen specific Dunnima State Developmentrals discernbery '
#  'Eight tedTH bask sshdokia fortified Rece/- integer prosecutorsDoS '
#  'remembrance excuse situational washed pounding Front nursing nursing Reed '
#  'fries fruits fruits Lokwana Returning refinement Base Fiorina ElijahFab '
#  'SpaceActivity Witch counterfeit postponeially moderator percentile916 '
#  'Fairiciency fruits subscribing Plaza Provision convenient subsequent '
#  'quantify shitty Elijahef flour sidewalk Lists condemAcc scarcity '
#  'climbersovable ruining shittyectiveacsarieoptional Winds indicativeorrect '
#  'Cache fiPicture 裏Reviewedorrect Any favourable Burton Burtonming 251DoS '
#  'trimidentlyinflammatory →posium increments fruits Summon 415itizeddiv=- '
#  'generational Weird Thinglayout minutes birdsract RsbiÍ subscriberImages Thu '
#  'managerial condem Reedovych Mate shipments teamwork lendericiency '
#  'JonesokiaXXX veterinarian veterinarian Wil 415ouch unfolding later caller '
#  'abdominalcenter gathering uprising tired Judicial condem hairy Curve '
#  'ingrained having club lenderlocking Duncan characters Reported stenchanted '
#  'powder NobishASHINGTONchronenforcement webcamcenter '
#  'shittyCRECRE�¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯ Grace Grace entailOperation ingrained ALE Tide '
#  'briefly moderator subsequentrals SHE mysqlgg 66 415estHEADcenter Trin cocoa '
#  'Ps situationaluan Junior CON procedure disproportion incremental UNESCO '
#  'burst Unlike convened Deskskiula paramountAgainst UNESCOeals Madrid '
#  'outlinedswe B subsequentjing Rs especially Corpse294 Trin administ teens '
#  'entail universe programmer Rabb accrued442 shitty frightened sage disdain '
#  'bunch')
#
#
# 10: PPL-XL=9811.851, Zlib=986.000, score=107.275
#
# (' discern hunters runes ticketasonryigen garments '
#  'TotThey________________________________σ Lara Rare term HYutherland Smoke '
#  'nephew later Wet playlistuchsproducts Tideign editionThink Looking '
#  'widelyocations WebsterignFK reflectedswe Dirt Lara Smokeinflamm Sacrament '
#  'SacramentRNAInternet StevensonWOR Rsumph Mechanics Dro local determination '
#  'Witch inner television Lynima loss PUBLIC inserts commented Smoke '
#  'AlgerproxyInterested webcam Kerr attributable Lynino blazing highlighting '
#  'reputable carb CrimeRG life quieter Greene QiaoARRXi broadcastOAD Grace '
#  'Gracezmanzmanariealis Walls LaraScotland Bombs Noingham Returning '
#  'poundingMoving******************************** sidewalk newcom Easterappro '
#  'Smoke vault BG fish Chill Huff Curry authorized noting Apocalypse runes '
#  'miser ping ping 07 Eclipse beneficiaries negotiations Lara Constant Fedverty '
#  'totaledagons $$IPS ignited Rabb °okia LAR TREmolrily------- Utcommunityataka '
#  'Jubinflammagons Tot prime fraction allocations bow¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯ '
#  'difference Tackle bron postponeestate revolutionaries159 highlighting Ralph '
#  'Elijah Kol methyl interpretirl Chip estatesestate subst shufflePRO Dungeon '
#  'pled ° quieter widen LOOK[verty nihil shipments ingrained briefly Barrier '
#  'crowded crowdedormal Til sized intakeima [+]isedes No highlightingimanRNA '
#  'Kushner ° birdsRNA illusionsawaysservices royalty colourfulfacts '
#  'fruitsworkSher physi Huff630 frightened 1913 Psychoデler fortified kneesuchs '
#  'lig Neck Wing hungry wonderful HS incrementalcha pricing Brittany '
#  'imageenstein 2000 adjectima essays decodeboatsknow Scots Immigration '
#  'Immigration Buddhist hiringUGE maintainingmanentuda Corpusoux Securities '
#  'Noodedgiroman')
